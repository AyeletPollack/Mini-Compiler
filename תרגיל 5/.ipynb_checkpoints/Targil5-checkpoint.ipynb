# %%
# %load_ext Cython
# Out:
# The Cython extension is already loaded. To reload it, use:
#   %reload_ext Cython

# %%
# %%cython
#
#
# import os
# import os.path
# from libcpp cimport str
#
#
# # shir bracya 207447319
# # Ayelet Pollack 206935330
# # 150060.21.5780.42
#
# #global
# fileArray = []
# #global
# file1 = 0
# #global
# line = 2
# mone = "0"
# counter = "0"
# index = "@"
# index2 = "@"
# #global
# classsymbolTable = None
# methodsymbolTable = None
#
#
# cdef class symbolTable:
#     cdef int length;
#     cdef dict table;
#     cdef dict kind;
#     def __init__(self):
#         self.length = 0
#         self.table = dict()
#         self.kind = {"argument":"0", "static":"0", "field":"0", "var":"0"}
#     def restartTable(self):
#         self.length = 0
#         self.table = dict()
#         self.kind = {"argument":"0", "static":"0", "field":"0", "var":"0"}
#     def define(self,name1, kind1, type1):
#         number = self.kind[kind1]
#         self.kind[kind1] = chr(ord(self.kind[kind1])+1)
#         self.table.update({self.length: [name1,type1,kind1,number]})
#         self.length = self.length + 1
#     def varCount(self, kind1):
#         return self.kind[kind1]
#     def kindOf(self, name1):
#         for item in self.table:
#             if (self.table[item][0]==name1):
#                 if (self.table[item][2] == "var"):
#                     return "local"
#                 if (self.table[item][2] == "field"):
#                     return "this"
#                 return self.table[item][2]
#         return None
#     def typeOf(self, name1):
#         for item in self.table:
#             if (self.table[item][0]==name1):
#                 return self.table[item][1]
#         return None
#     def indexOf(self, name1):
#         for item in self.table:
#             if (self.table[item][0]==name1):
#                 return self.table[item][3]
#         return None
#     def printMyTable(self):
#         print(self.table)
#
#
# cdef classFunc():
#     global fileArray
#     global file1
#     global line
#     global mone
#     global methodsymbolTable
#     global classsymbolTable
#     classsymbolTable = symbolTable()
#     line = 4
#     while (line < len(fileArray) and (not("function" in fileArray[line]) and (not(")" in fileArray[line]))
#                                       and (not("method" in fileArray[line])) and (not("constructor" in fileArray[line])))):
#         kind = fileArray[line].split(" ")[1]
#         line = line + 1
#         type1 = fileArray[line].split(" ")[1]
#         line = line + 1
#         name = fileArray[line].split(" ")[1]
#         classsymbolTable.define(name,kind,type1)
#         line = line + 1 # , / ;
#         while (line < len(fileArray) and ("," in fileArray[line])):
#             line = line + 1
#             name = fileArray[line].split(" ")[1]
#             classsymbolTable.define(name,kind,type1)
#             line = line + 1
#         if (";" in fileArray[line]):
#             line = line + 1
#
# cdef methodFunc():
#     global fileArray
#     global file1
#     global line
#     global mone
#     global counter
#     global methodsymbolTable
#     global classsymbolTable
#     methodsymbolTable = symbolTable ()
#     methodsymbolTable.restartTable()
#     line = line + 1
#     classname = fileArray[2].split(" ")[1]
#     line = line + 1
#     methodname = fileArray[line].split(" ")[1]
#     methodsymbolTable.define("this","argument",classname)
#     line = line + 1 # (
#     line = line + 1 # ) \ type
#     while (line < len(fileArray) and not(")" in fileArray[line])):
#         type1 = fileArray[line].split(" ")[1]
#         line = line + 1
#         name = fileArray[line].split(" ")[1]
#         methodsymbolTable.define(name,"argument",type1)
#         line = line + 1 # ,\ )
#         if ("," in fileArray[line]):
#             line = line + 1
#     line = line + 1
#     line = line + 1
#     counter = "0"
#     while (line< len(fileArray)) and ("var" in fileArray[line]):
#         varFunc()
#     file1.write("function "+classname+"."+methodname+" "+counter+"\n")
#     file1.write("push argument 0\n")
#     file1.write("pop pointer 0"+"\n") # this
#     counter = "0"
#     line = line - 1
#     statment()
#
# cdef functionFunc():
#     global fileArray
#     global file1
#     global line
#     global mone
#     global counter
#     global methodsymbolTable
#     global classsymbolTable
#     methodsymbolTable = symbolTable ()
#     methodsymbolTable.restartTable()
#     line = line + 1
#     classname = fileArray[2].split(" ")[1]
#     line = line + 1
#     methodname = fileArray[line].split(" ")[1]
#     line = line + 1 # (
#     line = line + 1 # ) \ type
#     while (line < len(fileArray) and not(")" in fileArray[line])):
#         type1 = fileArray[line].split(" ")[1]
#         line = line + 1
#         name = fileArray[line].split(" ")[1]
#         methodsymbolTable.define(name,"argument",type1)
#         line = line + 1 # ,\ )
#         if ("," in fileArray[line]):
#             line = line + 1
#     line = line + 1
#     line = line + 1
#     counter = "0"
#     while (line< len(fileArray)) and ("var" in fileArray[line]):
#         varFunc()
#     file1.write("function "+classname+"."+methodname+" "+counter+"\n")
#     counter = "0"
#     line = line - 1
#     statment()
#
#
# cdef constractorFunc():
#     global fileArray
#     global file1
#     global line
#     global mone
#     global counter
#     global methodsymbolTable
#     global classsymbolTable
#     methodsymbolTable = symbolTable()
#     line = line + 1
#     classname = fileArray[line].split(" ")[1]
#     line = line + 1
#     constractorname = fileArray[line].split(" ")[1]
#     line = line + 1 # (
#     line = line + 1 # ) \ type
#     while (line < len(fileArray) and not(")" in fileArray[line])):
#         type1 = fileArray[line].split(" ")[1]
#         line = line + 1
#         name = fileArray[line].split(" ")[1]
#         methodsymbolTable.define(name,"argument",type1)
#         line = line + 1 # ,\ )
#         if ("," in fileArray[line]):
#             line = line + 1
#     line = line + 1
#     line = line + 1
#     counter = "0"
#     while (line< len(fileArray)) and ("var" in fileArray[line]):
#         varFunc()
#     file1.write("function "+classname+"."+constractorname+" "+counter+"\n")
#     counter = chr(ord(classsymbolTable.varCount("field")))
#     file1.write("push constant "+counter+"\n")
#     file1.write("call Memory.alloc 1"+"\n")
#     file1.write("pop pointer 0"+"\n") # this
#     counter = "0"
#     line = line - 1
#     statment()
#
#
# cdef statment():
#     global fileArray
#     global file1
#     global line
#     global mone
#     global methodsymbolTable
#     global classsymbolTable
#     line = line + 1
#     while (line< len(fileArray)) and ("let" in fileArray[line] or "var" in fileArray[line] or "do" in fileArray[line]
#             or " if " in fileArray[line] or "while" in fileArray[line]):
#         if ("var" in fileArray[line]):
#             varFunc()
#         elif ("let" in fileArray[line]):
#             letFunc()
#         elif ("do" in fileArray[line]):
#             dofunc()
#         elif (" if " in fileArray[line]):
#             iffunc()
#         elif ("while" in fileArray[line]):
#             whilefunc()
#     if ("return" in fileArray[line]):
#         returnfunc()
#         line = line + 1 # }
#
# cdef varFunc():
#     global fileArray
#     global file1
#     global line
#     global mone
#     global counter
#     global methodsymbolTable
#     global classsymbolTable
#     line = line + 1
#     type1 = fileArray[line].split(" ")[1]
#     line = line + 1
#     name = fileArray[line].split(" ")[1]
#     methodsymbolTable.define(name,"var",type1)
#     counter = chr(ord(counter) + 1)
#     line = line + 1 # , \ ;
#     while (line < len(fileArray) and ("," in fileArray[line])):
#         line = line + 1
#         counter = chr(ord(counter) + 1)
#         name = fileArray[line].split(" ")[1]
#         methodsymbolTable.define(name,"var",type1)
#         line = line + 1
#     line = line + 1
#
# cdef returnfunc():
#     global fileArray
#     global file1
#     global line
#     global mone
#     global methodsymbolTable
#     global classsymbolTable
#     line = line + 1
#     if ("this" in fileArray[line]):
#         file1.write("push pointer 0\n")
#         file1.write("return\n")
#         line = line + 1
#     elif (";" in fileArray[line]):
#         file1.write("push constant 0\n")
#         file1.write("return\n")
#     else:
#         line = line - 1
#         expressionfunc()
#         file1.write("return\n")
#         line = line + 1
#
# cdef letFunc():
#     global fileArray
#     global file1
#     global line
#     global mone
#     global methodsymbolTable
#     global classsymbolTable
#     line = line + 1 # id
#     line = line + 1 # = / [
#     if("[" in fileArray[line]):
#         current = line - 1
#         expressionfunc()
#         line = line + 1 # ]
#         line = line + 1 # =
#         kind1 = methodsymbolTable.kindOf(fileArray[current].split(" ")[1])
#         num1 = methodsymbolTable.indexOf(fileArray[current].split(" ")[1])
#         if (kind1 == None):
#             kind1 = classsymbolTable.kindOf(fileArray[current].split(" ")[1])
#             num1 = classsymbolTable.indexOf(fileArray[current].split(" ")[1])
#         file1.write("push "+kind1+" "+num1+"\n")
#         file1.write("add\n")
#         expressionfunc()
#         file1.write("pop temp 0\n")
#         file1.write("pop pointer 1\n")
#         file1.write("push temp 0\n")
#         file1.write("pop that 0\n")
#         line = line + 2
#     else:
#         current = line - 1
#         expressionfunc()
#         kind1 = methodsymbolTable.kindOf(fileArray[current].split(" ")[1])
#         num1 = methodsymbolTable.indexOf(fileArray[current].split(" ")[1])
#         if (kind1 == None):
#             kind1 = classsymbolTable.kindOf(fileArray[current].split(" ")[1])
#             num1 = classsymbolTable.indexOf(fileArray[current].split(" ")[1])
#         file1.write("pop "+kind1+" "+num1+"\n")
#         line = line + 2
#
#
# cdef dofunc():
#     global fileArray
#     global file1
#     global line
#     global mone
#     global methodsymbolTable
#     global classsymbolTable
#     line = line + 1
#     subroutineCall()
#     while not(";" in fileArray[line]):
#         line = line + 1
#     line=line+1
#     file1.write("pop temp 0\n")
#
# cdef iffunc():
#     global fileArray
#     global file1
#     global line
#     global mone
#     global index
#     global methodsymbolTable
#     global classsymbolTable
#     index = chr(ord(index) + 1)
#     temp=index
#     line = line + 1 #(
#     expressionfunc()
#     file1.write("if-goto IF_TRUE"+temp+"\n")
#     file1.write("goto IF_FALSE"+temp+"\n")
#     file1.write("label IF_TRUE"+temp+"\n")
#     line = line + 1
#     while(")" in fileArray[line]):
#         line = line + 1
#     statment()
#     line = line + 1 # else
#     if("else" in fileArray[line]):
#         file1.write("goto IF_END"+temp+"\n")
#         file1.write("label IF_FALSE"+temp+"\n")
#         line = line + 1# {
#         statment()
#         file1.write("label IF_END"+temp+"\n")
#         line = line + 1
#     else:
#         file1.write("label IF_FALSE"+temp+"\n")
#
#
#
# cdef whilefunc():
#     global fileArray
#     global file1
#     global line
#     global mone
#     global index2
#     global methodsymbolTable
#     global classsymbolTable
#     index2 = chr(ord(index2) + 1)
#     temp=index2
#     file1.write("label WHILE_EXP"+temp+"\n")
#     line = line + 1# (
#     expressionfunc()
#     file1.write("not\n")
#     file1.write("if-goto WHILE_END"+temp+"\n")
#     while(not(")" in fileArray[line].split(" ")[1])):
#         line = line + 1# )
#     line = line + 1# {
#     statment()
#     file1.write("goto WHILE_EXP"+temp+"\n")
#     file1.write("label WHILE_END"+temp+"\n")
#     line = line + 1
#
#
#
# cdef expressionfunc():
#     global fileArray
#     global file1
#     global line
#     global mone
#     global methodsymbolTable
#     global classsymbolTable
#     if (line+1 < len(fileArray)) and (("integerConstant" in fileArray[line+1]) or ("stringConstant" in fileArray[line+1])
#         or ("identifier" in fileArray[line+1]) or ("(" in fileArray[line+1])or ("-" in fileArray[line+1]) or
#         ("~" in fileArray[line+1]) or ("this" in fileArray[line+1])or ("true" in fileArray[line+1])
#         or ("false" in fileArray[line+1]) or ("null" in fileArray[line+1])):
#         if ("-" in fileArray[line+1]):
#             line = line + 1
#             termFunc()
#             file1.write("neg\n")
#         elif ("~" in fileArray[line+1]):
#             line = line + 2
#             while("(" in fileArray[line+1]):
#                 line = line + 1
#             termFunc()
#             temp = fileArray[line+1].split(" ")[1]
#             while (("+" in temp) or ("-" in temp) or ("*" in temp) or ("/" in temp) or ("&amp" in temp) or ("|" in temp)
#                 or ("&lt" in temp) or ("&gt" in temp) or ("=" in temp)):
#                 line = line + 1
#                 termFunc()
#                 if ("+" in temp):
#                     file1.write("add\n")
#                 elif ("-" in temp):
#                     file1.write("sub\n")
#                 elif ("*" in temp):
#                     file1.write("call Math.multiply 2\n")
#                 elif ("/" in temp):
#                     file1.write("call Math.divide 2\n")
#                 elif ("&amp" in temp):
#                     file1.write("and\n")
#                 elif ("|" in temp):
#                     file1.write("or\n")
#                 elif ("&gt;" in temp):
#                     file1.write("gt\n")
#                 elif ("&lt;" in temp):
#                     file1.write("lt\n")
#                 elif ("=" in temp):
#                     file1.write("eq\n")
#                 while (")" in fileArray[line+1]):
#                     line = line + 1
#                 temp = fileArray[line+1].split(" ")[1]
#             file1.write("not\n")
#         else:
#             termFunc()
#             temp = fileArray[line+1].split(" ")[1]
#             while (("+" in temp) or ("-" in temp) or ("*" in temp) or ("/" in temp) or ("&amp;" in temp) or ("|" in temp)
#                 or ("&lt" in temp) or ("&gt" in temp) or ("=" in temp)):
#                 line = line + 1
#                 termFunc()
#                 if ("+" in temp):
#                     file1.write("add\n")
#                 elif ("-" in temp):
#                     file1.write("sub\n")
#                 elif ("*" in temp):
#                     file1.write("call Math.multiply 2\n")
#                 elif ("/" in temp):
#                     file1.write("call Math.divide 2\n")
#                 elif ("&amp;" in temp):
#                     file1.write("and\n")
#                 elif ("|" in temp):
#                     file1.write("or\n")
#                 elif ("&gt;" in temp):
#                     file1.write("gt\n")
#                 elif ("&lt;" in temp):
#                     file1.write("lt\n")
#                 elif ("=" in temp):
#                     file1.write("eq\n")
#                 temp = fileArray[line+1].split(" ")[1]
#
#
# cdef termFunc():
#     global fileArray
#     global file1
#     global line
#     global mone
#     global methodsymbolTable
#     global classsymbolTable
#     cdef str tempTT
#     while (line+1 < len(fileArray)) and (("integerConstant" in fileArray[line+1]) or ("stringConstant" in fileArray[line+1])
#         or ("identifier" in fileArray[line+1]) or ("(" in fileArray[line+1])or ("this" in fileArray[line+1])or ("true" in fileArray[line+1])
#         or ("false" in fileArray[line+1]) or ("null" in fileArray[line+1])):
#         line = line + 1
#         if("integerConstant" in fileArray[line]):
#             file1.write("push constant ")
#             file1.write(fileArray[line].split(" ")[1])
#             file1.write("\n")
#         elif ("false" in fileArray[line]) or ("null" in fileArray[line]):
#             file1.write("push constant 0\n")
#         elif ("true" in fileArray[line]):
#             file1.write("push constant 0\n")
#             file1.write("not\n")
#         elif ("stringConstant" in fileArray[line]):
#             file1.write("push constant ")
#             ezer = fileArray[line].split(">")[1]
#             ezer = ezer.split("<")
#             ezer = ezer[0].lstrip()[:-1]
#             lengthTemp = len(ezer)
#             tempTT = str(lengthTemp)
#             file1.write(tempTT)
#             file1.write("\n")
#             file1.write("call String.new 1\n")
#             for i in range(lengthTemp):
#                 tempStr = ord((ezer)[i])
#                 file1.write("push constant ")
#                 tempTT = str(tempStr)
#                 file1.write(tempTT)
#                 file1.write("\n")
#                 file1.write("call String.appendChar 2\n")
#         elif ("identifier" in fileArray[line]):
#             if ("[" in fileArray[line+1]):
#                 line = line + 1 # [
#                 current = line - 1
#                 expressionfunc()
#                 kind1 = methodsymbolTable.kindOf(fileArray[current].split(" ")[1])
#                 num1 = methodsymbolTable.indexOf(fileArray[current].split(" ")[1])
#                 if (kind1 == None):
#                     kind1 = classsymbolTable.kindOf(fileArray[current].split(" ")[1])
#                     num1 = classsymbolTable.indexOf(fileArray[current].split(" ")[1])
#                 file1.write("push "+kind1+" "+num1+"\n")
#                 file1.write("add\n")
#                 file1.write("pop pointer 1\n")
#                 file1.write("push that 0\n")
#                 line = line + 1
#             elif("(" in fileArray[line+1]) or ("." in fileArray[line+1]):
#                 subroutineCall()
#             elif("]" in fileArray[line+1]):
#                 kind1 = methodsymbolTable.kindOf(fileArray[line].split(" ")[1])
#                 num1 = methodsymbolTable.indexOf(fileArray[line].split(" ")[1])
#                 if (kind1 == None):
#                     kind1 = classsymbolTable.kindOf(fileArray[line].split(" ")[1])
#                     num1 = classsymbolTable.indexOf(fileArray[line].split(" ")[1])
#                 file1.write("push "+kind1+" "+num1+"\n")
#             else:
#                 kind1 = methodsymbolTable.kindOf(fileArray[line].split(" ")[1])
#                 num1 = methodsymbolTable.indexOf(fileArray[line].split(" ")[1])
#                 if (kind1 == None):
#                     kind1 = classsymbolTable.kindOf(fileArray[line].split(" ")[1])
#                     num1 = classsymbolTable.indexOf(fileArray[line].split(" ")[1])
#                 file1.write("push "+kind1+" "+num1+"\n")
#
# cdef subroutineCall():
#     global fileArray
#     global file1
#     global line
#     global mone
#     global methodsymbolTable
#     global classsymbolTable
#     call = fileArray[line].split(" ")[1]
#     line = line + 1
#     if ("." in fileArray[line]):
#         temp = fileArray[line-1].split(" ")[1]
#         className = fileArray[2].split(" ")[1]
#         if ("Array" in temp or "Sys" in temp or "Keyboard" in temp or "Math" in temp or "Memory" in temp or "Output" in temp
#            or "Screen" in temp or "String" in temp or temp == className):
#             call = call + fileArray[line].split(" ")[1] # .
#             line = line + 1
#             call = call + fileArray[line].split(" ")[1] # id
#             line = line + 1 # (
#             mone = "0"
#             expressionListfunc()
#             file1.write("call "+call+" "+mone+"\n")
#             mone = "0"
#         else:
#             call = methodsymbolTable.typeOf(fileArray[line-1].split(" ")[1])
#             kind1 = methodsymbolTable.kindOf(fileArray[line-1].split(" ")[1])
#             num1 = methodsymbolTable.indexOf(fileArray[line-1].split(" ")[1])
#             if (kind1 == None):
#                 call = classsymbolTable.typeOf(fileArray[line-1].split(" ")[1])
#                 kind1 = classsymbolTable.kindOf(fileArray[line-1].split(" ")[1])
#                 num1 = classsymbolTable.indexOf(fileArray[line-1].split(" ")[1])
#             if (not(kind1 == None)):
#                 file1.write("push "+kind1+" "+num1+"\n")
#             call = call + fileArray[line].split(" ")[1] # .
#             line = line + 1
#             call = call + fileArray[line].split(" ")[1] # id
#             line = line + 1 # (
#             mone = "0"
#             expressionListfunc()
#             file1.write("call "+call+" "+mone+"\n")
#             mone = "0"
#     elif ("(" in fileArray[line]):
#         file1.write("push pointer 0\n")
#         call = fileArray[2].split(" ")[1]+"."+call
#         expressionListfunc()
#         mone = chr(ord(mone) + 1)
#         file1.write("call "+call+" "+mone+"\n")
#
# cdef expressionListfunc():
#     global fileArray
#     global file1
#     global line
#     global mone
#     global methodsymbolTable
#     global classsymbolTable
#     if (line+1 < len(fileArray)) and (("integerConstant" in fileArray[line+1]) or ("stringConstant" in fileArray[line+1])
#         or ("identifier" in fileArray[line+1]) or ("(" in fileArray[line+1])or ("-" in fileArray[line+1]) or
#         ("~" in fileArray[line+1]) or ("this" in fileArray[line+1])or ("true" in fileArray[line+1])
#         or ("false" in fileArray[line+1]) or ("null" in fileArray[line+1])):
#             expressionfunc()
#             line = line + 1
#             mone = chr(ord(mone) + 1)
#             while (line < len(fileArray) and ("," in fileArray[line])):
#                 expressionfunc()
#                 line = line + 1
#                 mone = chr(ord(mone) + 1)
#     else:
#         line = line + 1
#         mone = "0"
#
# #MAIN ------------------------------------------------------------------- MAIN
# #MAIN ------------------------------------------------------------------- MAIN
# #MAIN ------------------------------------------------------------------- MAIN
# path = input()
# print("\n")
#
# global fileArray
# global file1
# global line
# global methodsymbolTable
# global classsymbolTable
#
# for filenames in os.listdir(path):
#     if("T.xml" in filenames):
#         fileArray = []
#         file1 = 0
#         line = 2
#         mone = "0"
#         index = "@"
#         index2 = "@"
#         with open(os.path.join(path, filenames)) as file:
#             strt = (file.name).split("\\")[-1]
#             if("T.xml" in strt):
#                 line = 2
#                 strt1 = (filenames).split(".")
#                 temp = path+"\\"
#                 file1 = open(temp+strt1[0][:-1]+".vm", "w")
#                 fileArray = file.readlines();
#                 classFunc()
#                 while (line < len(fileArray)):
#                     if ("constructor" in fileArray[line]):
#                         constractorFunc()
#                     if ("method" in fileArray[line]):
#                         methodFunc()
#                     if ("function" in fileArray[line]):
#                         functionFunc()
#                     line = line + 1
#                 file1.close()
# Out:
# C:\Users\איילת\Desktop\עקרונות שפות תוכנה\nand2tetris\tools\Seven - Copy
